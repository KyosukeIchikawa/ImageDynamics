# %% [markdown]
# # 画像の力学的観察 その1 ～波動方程式～
# 画素値を2次元のスカラー場と捉えて, 運動方程式を解くとどうなるか？<br>
# その1として波動方程式を計算。
# \begin{align}
# \frac{\partial^2 p}{\partial t^2} &= c^2\nabla^2 p \quad &{\rm (in \hspace{2pt} image)}, \\
# p &= 0 \quad &{\rm (on \hspace{2pt} image \hspace{2pt} boundary)}.
# \end{align}
# 面倒なので初速適当。<br>
# 慣性項とラプラシアンの平均化作用で振動しているように見える？

# %%
# %run py/image_dynamics_01.py ./caffe.jpg 20
