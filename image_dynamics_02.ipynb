# %% [markdown]
# # 画像の力学的観察 その2 ～拡散方程式～
# 画素値を2次元のスカラー場と捉えて, 運動方程式を解くとどうなるか？<br>
# その2として拡散方程式を計算。
# ![Wave Equation](./img/waveeq3.gif)
# ![Wave Equation](./img/waveeq4.gif)
# 温度分布が熱平衡を目指すように, RGBそれぞれが平均化されていく様子が見られる。<br>
# ちなみに, 私はコンタクトを外すとstep20くらいのボヤけた感じで見える。

# %%
# %run py/image_dynamics_02.py ./garden.jpg 20
